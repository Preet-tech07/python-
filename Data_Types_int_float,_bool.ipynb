# %% [markdown]
# <a href="https://colab.research.google.com/github/Preet-tech07/python-/blob/main/Data_Types_int_float%2C_bool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data types in python
#
# Python is a dynamically typed language, which means you don't need to declare the data type of a variable when you create it; Python will determine the data type dynamically at runtime. However, Python has several built-in data types that you can use to store and manipulate different kinds of data. Here are some of the most common data types in Python:
#
# * ### Numeric  - Numeric variables take values which are numbers like 9, 3.14, 0, Inf
#
#
# * ### String   - 'hello',"hello"
#
#
# * ### Boolean  - True, False
#
#
# * ### Datetime  - 2023-08-05 08:21:04

# %% [markdown]
# # Integers and Floats

# %%
a = 10
type(a)
# Out:
# int

# %%
a = 10234567
type(a)
# Out:
# int

# %%
a = 1023.4567
type(a)
# Out:
# float

# %%
a = 10.0
type(a)
# Out:
# float

# %%
a = 0.0
type(a)
# Out:
# float

# %%
a = True
type(a)
# Out:
# bool

# %%
a = False
type(a)
# Out:
# bool

# %% [markdown]
# ## Perform Arithmetic oprations

# %%
a = 10
b = 20

c = a+b
print(c)
# Out:
# 30

# %%
a = 10
b = 20

print(a+b)
# Out:
# 30

# %%
print(100+200)
# Out:
# 300

# %%
a = 10
b = 20

print(a-b)
# Out:
# -10

# %%
print(a*b)
# Out:
# 200

# %%
a = 10
b = 2

print(a/b)
# Out:
# 5.0

# %%
a = 10
b = 3

print(a/b)
# Out:
# 3.3333333333333335

# %%
a = 10
b = 3

print(a//b)
# Out:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 10
b = 3

print(a%b)
# Out:
# 1

# %%
a = 11
b = 3

print(a%b)
# Out:
# 2

# %%
a = 12
b = 3

print(a%b)
# Out:
# 0

# %%
a = 3

print(a**3)
# Out:
# 27

# %%
a = 2

print(a**4)
# Out:
# 16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = (10*2)-(10/2)

print(a)
# Out:
# 15.0

# %% [markdown]
# ###  VARIABLES are entities which help us store information and retrieve it later.

# %%
rahul = 10

print(rahul)
# Out:
# 10

# %%
rahul = 10
Rahul = 20

print(Rahul)
# Out:
# 20

# %%
rahul singh = 10

print(rahul singh)
# Out:
#   File "/tmp/ipykernel_942/860381509.py", line 1
#     rahul singh = 10
#           ^
# SyntaxError: invalid syntax

# %%
rahul_singh = 10

print(rahul_singh)
# Out:
# 10

# %%
_rahul_singh_ = 10

print(_rahul_singh_)
# Out:
# 10

# %%
_rahul_singh_1 = 10

print(_rahul_singh_1)
# Out:
# 10

# %%
_rahul1_singh_1 = 10

print(_rahul1_singh_1)
# Out:
# 10

# %%
1_rahul1_singh_1 = 10

print(1_rahul1_singh_1)
# Out:
#   File "/tmp/ipykernel_942/3759140717.py", line 1
#     1_rahul1_singh_1 = 10
#      ^
# SyntaxError: invalid decimal literal

# %%
#~!@#$%^&*()-++=|}{[]\":;'?><,./₹"}

# %% [markdown]
# ## Comparison Operators
#
# Equal to ==
#
# Not equal to !=
#
# Greater than >
#
# Less than <
#
# Greater than or equal to >=
#
# Less than or equal to <=

# %%
a = 10
b = 20

print(a == b)
# Out:
# False

# %%
print(a != b)
# Out:
# True

# %%
print(a > b)
# Out:
# False

# %%
print(a < b)
# Out:
# True

# %%
print(a <= b)
# Out:
# True

# %%
print(a >= b)
# Out:
# False
