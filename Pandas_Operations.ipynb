# %% [markdown]
# <a href="https://colab.research.google.com/github/Preet-tech07/python-/blob/main/Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Yesterday, we learnt a little about the very useful library Pandas widely used for Data Analysis. It is time to put the many utilities of this library in front of our eyes. We will be performing following manipulations and exploration of our data:**
#
# * ### Indexing and slicing operations
# * ### Manipulating columns
# * ### Exploring unique and missing values

# %%
# Import pandas package
import pandas as pd
import numpy as np

# %%
# loading csv File
file_path = '/content/drive/MyDrive/Colab Notebooks/Data Set/imdb_data.csv'
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# # <u>**<code>describe()</code>**</u>
#
# ## This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
3.000000e+03
# Out:
# 3000.0

# %% [markdown]
# # <u>**Indexing and Slicing**</u>

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# ## **<code>iloc</code>** gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
#df.iloc[rows,columns]

# %%
df.iloc[:5,1:3]
# Out:
#                                belongs_to_collection    budget
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0

# %% [markdown]
# ## **<code>loc</code>** gets rows (or columns) with particular labels from the index.

# %%
#df.loc[rows,[columns_name]]

# %%
df.loc[:5,['title','runtime','belongs_to_collection']]
# Out:
#                                       title  runtime  \
# 0                    Hot Tub Time Machine 2     93.0
# 1  The Princess Diaries 2: Royal Engagement    113.0
# 2                                  Whiplash    105.0
# 3                                   Kahaani    122.0
# 4                                Marine Boy    118.0
# 5    Pinocchio and the Emperor of the Night     83.0
#
#                                belongs_to_collection
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
df.loc[:,['title','runtime']]
# Out:
#                                          title  runtime
# 0                       Hot Tub Time Machine 2     93.0
# 1     The Princess Diaries 2: Royal Engagement    113.0
# 2                                     Whiplash    105.0
# 3                                      Kahaani    122.0
# 4                                   Marine Boy    118.0
# ...                                        ...      ...
# 2995                                   Chasers    102.0
# 2996                          We Are the Best!    102.0
# 2997                   The Long Kiss Goodnight    120.0
# 2998                          Along Came Polly     90.0
# 2999                                 Abduction    106.0
#
# [3000 rows x 2 columns]

# %%
df[['title','runtime']]
# Out:
#                                          title  runtime
# 0                       Hot Tub Time Machine 2     93.0
# 1     The Princess Diaries 2: Royal Engagement    113.0
# 2                                     Whiplash    105.0
# 3                                      Kahaani    122.0
# 4                                   Marine Boy    118.0
# ...                                        ...      ...
# 2995                                   Chasers    102.0
# 2996                          We Are the Best!    102.0
# 2997                   The Long Kiss Goodnight    120.0
# 2998                          Along Came Polly     90.0
# 2999                                 Abduction    106.0
#
# [3000 rows x 2 columns]

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df[df['original_language'] == 'hi']
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 213    214                                                NaN   6700000
# 371    372                                                NaN  13100000
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# ...

# %%
hindi_movies = df[df['original_language'] == 'hi'][['title','original_language','runtime']]
hindi_movies
# Out:
#                                  title original_language  runtime
# 3                              Kahaani                hi    122.0
# 213                      Rowdy Rathore                hi    143.0
# 371                          Thank You                hi    140.0
# 401         The Legend of Bhagat Singh                hi    155.0
# 419   Dear Guest, When Will You Leave?                hi    155.0
# 481             Chandni Chowk To China                hi    149.0
# 585                             Dangal                hi    161.0
# 627                                Fan                hi    142.0
# 671                    Anjaana Anjaani                hi    151.0
# 695                          Tere Naam                hi    132.0
# 771                            Kaminey                hi    135.0
# 840                             Neerja                hi    122.0
# 848                         Raanjhanaa                hi    140.0
# ...

# %%
hindi_movies.shape
# Out:
# (42, 3)

# %%
df[df['runtime'] >120][['title','original_language','runtime']]
# Out:
#                     title original_language  runtime
# 3                 Kahaani                hi    122.0
# 12        American Beauty                en    122.0
# 14        Minority Report                en    145.0
# 20          Lost in Space                en    130.0
# 33        ABCs of Death 2                en    125.0
# ...                   ...               ...      ...
# 2969         Gosford Park                en    137.0
# 2970        The Bodyguard                en    129.0
# 2980     Action Hero Biju                ml    144.0
# 2992  The Thief of Bagdad                en    149.0
# 2993         The Terminal                en    128.0
#
# [657 rows x 3 columns]

# %% [markdown]
# # <u>**Next let us see how we can manipulate columns**</u>

# %%
df['runtime'].head()
# Out:
# 0     93.0
# 1    113.0
# 2    105.0
# 3    122.0
# 4    118.0
# Name: runtime, dtype: float64

# %%
df['half_runtime'] = df['runtime']/2
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime'],
#       dtype='object')

# %%
df['profit'] = df['revenue'] - df['budget']
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df['profit'].max()
# Out:
# 1316249360

# %%
df['profit'].min()
# Out:
# -107447384

# %%
df['profit'].sum()
# Out:
# np.int64(132583553336)

# %%
df['profit'].mean()
# Out:
# np.float64(44194517.77866667)

# %%
df['profit'].median()
# Out:
# 6121122.5

# %%
df['profit'].mode()
# Out:
# 0    0
# Name: profit, dtype: int64

# %% [markdown]
# ## **Next, we can also drop some columns which we want to drop**

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime', 'profit'],
#       dtype='object')

# %%
df.drop(columns=['half_runtime'],inplace=True)

# %%
df['title'].head()
# Out:
# 0                      Hot Tub Time Machine 2
# 1    The Princess Diaries 2: Royal Engagement
# 2                                    Whiplash
# 3                                     Kahaani
# 4                                  Marine Boy
# Name: title, dtype: object

# %%
def upper_case(column):
  return column.upper()

# %%
df['upper_title'] = df['title'].apply(upper_case)
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# ## Another way to use <code>apply()</code> involves the use of <code>lambda()</code> function.
#
# * ### A <code>lambda()</code> function is a small anonymous function.
# * ### A <code>lambda()</code> function can take any number of arguments, but can only have one expression.

# %%
def add_f(x,y):
  return x+y

# %%
add_f(10,20)
# Out:
# 30

# %%
x = lambda x,y:x+y

# %%
x(100,200)
# Out:
# 300

# %% [markdown]
# ## We can also sort our dataframe by some column values in either an ascending or descending order

# %%
df.sort_values(by = 'revenue',ascending = False)[['title','revenue']]
# Out:
#                                title     revenue
# 1126                    The Avengers  1519557910
# 1761                       Furious 7  1506249360
# 2770         Avengers: Age of Ultron  1405403694
# 684             Beauty and the Beast  1262886337
# 2322  Transformers: Dark of the Moon  1123746996
# ...                              ...         ...
# 695                        Tere Naam           2
# 1917                 The Merry Widow           1
# 347          The Wind in the Willows           1
# 1754                    Mute Witness           1
# 1874                         Missing           1
#
# [3000 rows x 2 columns]

# %% [markdown]
# # <b>Let us explore some datetime operations and functions

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['release_date'][0]
# Out:
# '2/20/15'

# %%
type(df['release_date'][0])
# Out:
# str

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
df['release_date'][0]
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
df['release_date'][0].year
# Out:
# 2015

# %%
df['release_date'][0].month
# Out:
# 2

# %%
df['release_date'][0].day
# Out:
# 20

# %%
df['release_date'][0].day_name()
# Out:
# 'Friday'

# %%
df['release_date'][0].weekday()
# Out:
# 4

# %%
df['release_date'][0].hour
# Out:
# 0

# %%
df['year'] = df['release_date'].dt.year
df['month'] = df['release_date'].dt.month
df['day'] = df['release_date'].dt.day
df['day_name'] = df['release_date'].dt.day_name()
df['weekday'] = df['release_date'].dt.weekday

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# # **Let's explore the unique and missing values**
#
# * ### <code>unique()</code>
# * ### <code>nunique()</code>
# * ### <code>value_counts()</code>
# * ### <code>isnull()</code>
# * ### <code>fillna()</code>

# %%
df['day_name'].head()
# Out:
# 0      Friday
# 1      Friday
# 2      Friday
# 3      Friday
# 4    Thursday
# Name: day_name, dtype: object

# %%
df['day_name'].unique()
# Out:
# array(['Friday', 'Thursday', 'Wednesday', 'Sunday', 'Tuesday', 'Saturday',
#        'Monday'], dtype=object)

# %%
df['day_name'].nunique()
# Out:
# 7

# %%
df['day_name'].value_counts()
# Out:
# day_name
# Friday       1332
# Thursday      604
# Wednesday     451
# Tuesday       200
# Saturday      156
# Monday        138
# Sunday        119
# Name: count, dtype: int64

# %%
df['weekday'].value_counts().sort_index()
# Out:
# weekday
# 0     138
# 1     200
# 2     451
# 3     604
# 4    1332
# 5     156
# 6     119
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# profit                      0
# upper_title                 0
# year                        0
# month                       0
# day                         0
# day_name                    0
# weekday                     0
# dtype: int64

# %%
df['production_countries'].isnull().sum()
# Out:
# np.int64(55)

# %%
df.describe()
# Out:
#                 id        budget   popularity                release_date  \
# count  3000.000000  3.000000e+03  3000.000000                        3000
# mean   1500.500000  2.253133e+07     8.463274  2006-10-31 08:24:57.600000
# min       1.000000  0.000000e+00     0.000001         1976-03-31 00:00:00
# 25%     750.750000  0.000000e+00     4.018053         1996-09-07 18:00:00
# 50%    1500.500000  8.000000e+06     7.374861         2006-07-26 12:00:00
# 75%    2250.250000  2.900000e+07    10.890983         2013-01-17 00:00:00
# max    3000.000000  3.800000e+08   294.337037         2075-10-17 00:00:00
# std     866.169729  3.702609e+07    12.104000                         NaN
#
#            runtime       revenue        profit         year        month  \
# count  2998.000000  3.000000e+03  3.000000e+03  3000.000000  3000.000000
# mean    107.856571  6.672585e+07  4.419452e+07  2006.313000     6.775333
# min       0.000000  1.000000e+00 -1.074474e+08  1976.000000     1.000000
# ...

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df['belongs_to_collection'].fillna('not present',inplace = True)
# Out:
# /tmp/ipykernel_434/1206371012.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['belongs_to_collection'].fillna('not present',inplace = True)

# %%
df['belongs_to_collection'].head()
# Out:
# 0    [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1    [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                                          not present
# 3                                          not present
# 4                                          not present
# Name: belongs_to_collection, dtype: object
